# %% [markdown]
# # FIT5196 Assessment 2
# #### Student Name: Meng Li, Xuejin Huang
# #### Student ID: 29040256, 28651073
#
# Date: 15/09/2019
#
# Version: 1.0
#
# Environment: Python 3.6.5 and Jupyter notebook
#
# Libraries used:
# * pandas (for dataframe, included in Anaconda Python 3.6)
# * re (for regular expression, included in Anaconda Python 3.6)
# * requests (for download pdf files)
# * nltk (for text pre-processing)
# * pdfminer (for parsing pdf files)

# %% [markdown]
# ## 1.  Introduction
#
# This assignment is about text pre-processing and feature generation. The dataset includes 200 papers in pdf format, which are downloaded at the first step. Then the papers in pdf format are convert to txt format, where will carry out text pre-processing including tokenization, stemming and some other processes. The text pre-processing is based on two main parts of the paper, one is the paper bodies and the other part includes title, authors and abstracts.
#
# After text-preprocessing, the tokens from paper bodies will be used to generate a vocabulary index and a sparse count vectors file. As for tokens from the other part, the top 10 most frequent terms in title and abstract and the the top 10 most frequent authors will be found.
#
# The output of this assignment should including the following:
# 1. vocabulary index file
# 2. sparse count vectors file
# 3. csv file containing the top 10 most frequent terms in title, abstract and authors

# %% [markdown]
# ## 2. Import libraries
#
# In this assignment, the most important library is the `nltk` library, which is responsible for the text pre-processing such as tokenization and stemming. There are also some other libraries, for example, `re` library is responsible for regular expression and the `requests` library is responsible for downloading. The comments in the coding part describe each import's functions.

# %%
# these pdfminer packages are used in the convert_pdf_to_txt function, to convert the pdf to txt
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage

#re packages are used for every time we need to parsing the word.
import re

#request package used in download part, it used to send a HTTP request and get the response,
# download the pdf files using the url in Group006.df
import requests

# sys package is used for the file write and read 
import sys

# These ntlk packages are used for tokenization
import nltk
import itertools
from nltk.util import ngrams # This package is used for bigram at first.
from itertools import chain # when find the 200 meaningful bigrams, we used this package, we used list.chain in our code
from nltk.collocations import *
from nltk.probability import *
import nltk.data #This package is imported because we need to do the sentence segmentation
from nltk.tokenize import RegexpTokenizer # We use this package because we have to tokenization using the given regex
from nltk.tokenize import MWETokenizer #MWETokenizer package is for the subtitu the words after bigram.
from nltk.stem.porter import PorterStemmer #This package is used to do the stemmer work
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer # This package is for count the numbers of words.

# These packages are used for the output
import pandas as pd # pandas imported to make the CSV format
from io import StringIO # This packages used for output our result as files.

# %% [markdown]
# ## 3. Downloading the pdf files and converting to txt
#
# In this part, a pdf file containing the paper number (name, such as PP3295) and the corresponding urls is parsed at first. Then the paper name and its urls are extracted. After that, the 200 papers pdf files (the dataset) are downloaded and stored in a dictionary, where the key is the paper name and the value is the paper content in txt format.

# %% [markdown]
# ### 3.1 Parsing the 'Group006.pdf'
#
# In this section, the `Group006.pdf` is parsed. The important information including the paper name and the urls are extracted and then stored in the lists.

# %%
# This method is used to convert pdf to txt
# Reference: https://stackoverflow.com/questions/26494211/extracting-text-from-a-pdf-file-using-pdfminer-in-python

def convert_pdf_to_txt(path):
    rsrcmgr = PDFResourceManager()
    retstr = StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    fp = open(path, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 0
    caching = True
    pagenos=set()

    for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages, password=password,caching=caching, check_extractable=True):
        interpreter.process_page(page)

    text = retstr.getvalue()

    fp.close()
    device.close()
    retstr.close()
    return text

# %%
# Convert the Group006.pdf to txt format
Group006_txt = convert_pdf_to_txt('Group006.pdf')

# %%
# Extract the pdf names such as 'PP3295'
regex = r'\n(.*)?\.pdf'
name = re.findall(regex, Group006_txt)
# print(name)

# %%
# Extract the URLs for downloading
regex = r' (.*)?\n'
url = re.findall(regex, Group006_txt)
# print(url)

# %% [markdown]
# ### 3.2 Downloading the dataset (200 papers in pdf) and convert to txt format
#
# In this section, the 200 papers in pdf format are downloaded to the local site using the urls extracted in the previous step. Then the pdf is converted to the txt format, which is prepared for the text pre-processing, and then each paper and its content are stored in a dictionary.

# %%
# Download the 200 pdfs to local
for i in range(0,200):    
    filename = './' + name[i] + '.pdf'
    r = requests.get(url[i])
    with open(filename, 'wb') as f:
        f.write(r.content)

# %%
# Convert the pdf to the text, 
# then create a dictionary to store the names and corresponding content.
txtdic = {}
for aname in name:
    pdfname = aname + '.pdf'
    value = convert_pdf_to_txt(pdfname)
    txtdic[aname] = value

# %%
# txtdic['PP3295']
# Out:
# 'Discriminative Batch Mode Active Learning\n\nAuthored by:\n\nDale Schuurmans\n\nYuhong Guo\n\nAbstract\n\nActive learning sequentially selects unlabeled instances to label with\nthe goal of reducing the eﬀort needed to learn a good classiﬁer. Most\nprevious studies in active learning have focused on selecting one unla-\nbeled instance at one time while retraining in each iteration. However,\nsingle instance selection systems are unable to exploit a parallelized la-\nbeler when one is available. Recently a few batch mode active learning\napproaches have been proposed that select a set of most informative unla-\nbeled instances in each iteration, guided by some heuristic scores. In this\npaper, we propose a discriminative batch mode active learning approach\nthat formulates the instance selection task as a continuous optimization\nproblem over auxiliary instance selection variables. The optimization is\nformuated to maximize the discriminative classiﬁcation performance of\nthe target classiﬁer, while also taking the unlabeled data into account.\nAlthough the objective is not convex, we can manipulate a quasi-Newton\nmethod to obtain a good local solution. Our empirical studies on UCI\ndatasets show that the proposed active learning is more eﬀective than\ncurrent state-of-the art batch mode active learning algorithms.\n\n1 Paper Body\n\nLearning a good classiﬁer requires a suﬃcient number of labeled training in-\nstances. In many circumstances, unlabeled instances are easy to obtain, while\nlabeling is expensive or time consuming. For example, it is easy to download\na large number of webpages, however, it typically requires manual eﬀort to\nproduce classiﬁcation labels for these pages. Randomly selecting unlabeled in-\nstances for labeling is ineﬃcient in many situations, since non-informative or\nredundant instances might be selected. Hence, active learning (i.e., selective\nsampling) methods have been adopted to control the labeling process in many\nareas of machine learning, with the goal of reducing the overall labeling eﬀort.\nGiven a large pool of unlabeled instances, active learning provides a way to\niteratively select the most informative unlabeled instances?the queries?to label.\nThis is the typical setting of poolbased active learning. Most active learning\napproaches, however, have focused on selecting only one unlabeled instance at\n\n1\n\n\x0cone time, while retraining the classiﬁer on each iteration. When the training\nprocess is hard or time consuming, this repeated retraining is ineﬃcient. Fur-\nthermore, if a parallel labeling system is available, a single instance selection\nsystem can make wasteful use of the resource. Thus, a batch mode active learn-\ning strategy that selects multiple instances each time is more appropriate under\nthese circumstances. Note that simply using a single instance selection strategy\nto select more than one unlabeled instance in each iteration does not work well,\nsince it fails to take the information overlap between the multiple instances into\naccount. Principles for batch mode active learning need to be developed to ad-\ndress the multi-instance selection speciﬁcally. In fact, a few batch mode active\nlearning approaches have been proposed recently [2, 8, 9, 17, 19]. However,\nmost extend existing single instance selection strategies into multi-instance se-\nlection simply by using a heuristic score or greedy procedure to ensure both the\ninstance diversity and informativeness.\n\nIn this paper, we propose a new discriminative batch mode active learning\nstrategy that exploits information from an unlabeled set to attempt to learn\na good classiﬁer directly. We deﬁne a good classiﬁer to be one that obtains\nhigh likelihood on the labeled training instances and low uncertainty on la-\nbels of the unlabeled instances. We therefore formulate the instance selection\nproblem as an optimization problem with respect to auxiliary instance selection\nvariables, taking a combination of ...

# %% [markdown]
# ## 4. Text pre-processing of the paper bodies
#
# In this part, the paper bodies are extracted at the first and then the text pre-processing is carried out. Based on the assignment specification, there are several steps in the pre-processing, which will be discussed in the following sections.

# %% [markdown]
# ### 4.1 Tokenization and unigram
#
# In this section, the paper body is extracted from the paper and then the tokenization is carried out on each papar body. Based on specification, the tokens from the first word of a sentence are converted to the lower case.

# %%
# This is to create the object for sentence segmentation.
# nltk.download('punkt')
sent_detector = nltk.data.load('tokenizers/punkt/english.pickle')

# %%
# Extract the paper body and change the start of sentence to lower case
tokenizer = RegexpTokenizer(r"[A-Za-z]\w+(?:[-'?]\w+)?")

# This regex is used for extracting paper body
regex = r'Paper Body(.*)Reference' 

unigramdic = {}
for aname in name:
    paperbody = re.sub(r'(-\n)', '', txtdic[aname])
    paperbody = re.sub(r'(\n)', ' ', paperbody)
    paperBody = re.findall(regex, paperbody)
    sentences = sent_detector.tokenize(paperBody[0].strip())
    string = ''
    
    # Convert the first word in a sentence to lower case.
    for i in range(0,len(sentences)):
        string += sentences[i][0].lower() + sentences[i][1:]
    unigram_tokens = tokenizer.tokenize(string)
    
    # Use a dictionary to store tokens, where the key is the paper name 
    # and value is the tokens
    unigramdic[aname] = unigram_tokens

# %% [markdown]
# ### 4.2 First 200 meaningful bigrams
#
# In this section, the first 200 meaningful bigrams without stop words are extracted. Then the bigrams are replaced with the unigrams. For example, if a bigram is `artificial__intelligence`, then it will replace the unigram `artificial` and `intelligence` that appears together.

# %%
# Read the stop words
stop_list=[]
with open('./stopwords_en.txt') as f:
    stopwords = f.read().splitlines()
stopwords_set = set(stopwords)

# %%
# Find the first 200 meaningful bigrams
all_words = list(chain.from_iterable(unigramdic.values()))
bigrams = ngrams(all_words, n = 2)

# Get the total frequency of the bigrams
fdbigram = FreqDist(bigrams)
result_dic = {}
for k,v in fdbigram.items():
    if k[0] not in stopwords_set and k[1] not in stopwords_set: # Take the bigram without stopwords
        result_dic[k] = v   
sortedresult_dic = sorted(result_dic.items(), key=lambda x: x[1], reverse=True) # Sort and find the first 200
result_bigram = sortedresult_dic[0:200]

bigram_list = []
for i in result_bigram:
    bigram_list.append(i[0])

# %%
# Replace the unigrams with the corresponding bigrams
mwetokenizer = MWETokenizer(bigram_list, separator='__')
paperbody_dic =  dict((name, mwetokenizer.tokenize(content)) for name,content in unigramdic.items())

# %% [markdown]
# ### 4.3 Removing the stop words
#
# In this section, the stop words (context-independent) are removed from the tokens dictionary.

# %%
# Remove the stop words
for k,v in paperbody_dic.items():
    paperbody_dic[k] = [w for w in v if w.lower() not in stopwords_set]

# %% [markdown]
# ### 4.4 Unigram stemming
#
# In this section, the unigrams are stemmed. In particular, because the `PorterStemmer` will perform lower casing by default, we take out the tokens containing more than two capital letters with special meaning, such as 'USA'.

# %%
# Only stem the unigrams
# The regex is finding the bigrams and the token with more than two capital letters such as USA
# We don't stem these tokens
stemmer = PorterStemmer()
regex = r'\w*[A-Z_]\w*[A-Z_]\w*'
for k,v in paperbody_dic.items():
    astring = ' '
    astring = astring.join(v)
    no_stem = re.findall(regex, astring)
    no_stem_set = set(no_stem)
    stemmed_tokens = []
    stemmed_tokens = stemmed_tokens + [stemmer.stem(w) for w in v if w not in no_stem_set]
    
    # Add the non-stemmed tokens back
    stemmed_tokens = stemmed_tokens + no_stem
    
    paperbody_dic[k] = stemmed_tokens

# %% [markdown]
# ### 4.5 Removing token with the length less than 3

# %%
# Remove the words with length less than 3
for k, v in paperbody_dic.items():
    paperbody_dic[k] = [word for word in v if len(word)>=3]

# %% [markdown]
# ### 4.6 Remove the context-dependent tokens and rare tokens
#
# In this section, the token appearing more then 95% and less than 3% (based on the document frequency) are removed. First, we create a dictionary to store the document frequency of a token. Then, the token with document frequency more than 95% or less than 3% are stored in two lists.

# %%
# Create the two lists that store the document frequency morethan 0.95 or lessthan 0.03
more95 = []
less3 = []
word = {}
for k in paperbody_dic.keys():
    newlist = list(set(paperbody_dic[k]))
    for item in newlist:
        if item in word.keys():
            word[item] += 1
        else:
            word[item] = 1
for k,v in word.items():
    if v >= (200 * 0.95):
        more95.append(k)
    if v < (200 * 0.03):
        less3.append(k)

len(less3)
# Out:
# 15818

# %%
# Remove these context-dependent tokens and rare tokens
for k,v in paperbody_dic.items():
    paperbody_dic[k] = [w for w in v if w not in more95 and w not in less3]

# %% [markdown]
# ### 4.7 Create the vocab list and output the vocab index file
#
# The text pre-processing is finished for the paper body. In this section, we create the vocab index file and output as txt file.

# %%
# Create the vocabulary list
vocab = []
for v in paperbody_dic.values():
    vocab += v
vocab = list(set(vocab))
vocab_sorted = sorted(vocab)
print(vocab_sorted)
# Out:
# ['AUC', 'BFGS', 'Bayesian__approach', 'Beach__CA', 'CAREER', 'CCF', 'CDF', 'CIFAR', 'CNN', 'CPU', 'DARPA', 'DKL', 'ERC', 'Experiments__We', 'FP7', 'Figure__The', 'Fisher__information', 'GHz', 'GPU', 'GPUs', 'GPs', 'Gaussian__process', 'Gibbs__sampler', 'Gibbs__sampling', 'HMM', 'HMMs', 'III', 'IIS', 'ImageNet', 'In__order', 'KL__divergence', 'LASSO', 'LDA', 'LSTM', 'LeCun', 'MAP', 'MATLAB', 'MCMC', 'MDP', 'MDPs', 'MLE', 'MLP', 'MNIST', 'MSE', 'Markov__chain', 'Monte__Carlo', 'NIPS', 'NIPS__Barcelona', 'NIPS__Long', 'NSF', 'NVIDIA', 'Neural__Information', 'ONR', 'PAC', 'PCA', 'Processing__Systems', 'RAM', 'RBF', 'RGB', 'RHS', 'RKHS', 'RMSE', 'RNN', 'ROC', 'ReLU', 'SDP', 'SGD', 'SVD', 'SVM', 'SVMs', 'This__work', 'UCB', 'UCI', 'USA', 'W911NF', 'abbrevi', 'abil', 'absenc', 'absent', 'absolut', 'abstract', 'abund', 'abus', 'acc', 'acceler', 'accept', 'access', 'accomplish', 'accord', 'account', 'accumul', 'accur', 'accuraci', 'achiev', 'acknowledg', 'acquir', 'acquisit', 'act', 'action', 'activ', 'active__learning', 'actual', 'acycl', 'adam', 'adapt', 'add', 'addit', 'address', 'adequ', 'adjac', 'adjust', 'admit', 'adopt', 'advanc', 'advantag', 'adversari', 'advertis', 'advoc', 'aforement', 'age', 'agenc', 'agent', 'agent?', 'aggreg', 'agre', 'agreement', 'aid', 'aij', 'aim', 'akin', 'albeit', 'alg', 'algebra', 'algorithm', 'algorithm?', 'align', 'allevi', 'alloc', 'allow', 'alphabet', 'alter', 'altern', 'altogeth', 'amazon', 'ambient', 'ambigu', 'amen', 'amount', 'amplitud', 'analog', 'analogu', 'analys', 'analysi', 'analyt', 'analyz', 'ancestor', 'angl', 'anim', 'anneal', 'annot', 'anonym', 'answer', 'anticip', 'appar', 'appeal', 'appear', 'appendix', 'appli', 'applic', 'approach', 'appropri', 'approxim', 'approximate__inference', 'arbitrari', 'arbitrarili', 'architectur', 'archiv', 'area', 'arg', 'arg__min', 'argmax', 'argmin', 'argu', 'arguabl', 'argument', 'aris', 'arm', 'arrang', 'array', 'arriv', 'arrow', 'art', 'articl', 'artifact', 'artiﬁci', 'ascent', 'ask', 'aspect', 'assert', 'assess', 'assign', 'associ', 'assum', 'assumpt', 'assur', 'asymmetr', 'asymptot', 'asynchron', 'at?1', 'atom', 'attach', 'attain', 'attempt', 'attent', 'attract', 'attribut', 'augment', 'author', 'autoencod', 'autom', 'automat', 'auxiliari', 'avail', 'avenu', 'averag', 'avg', 'avoid', 'awar', 'award', 'axe', 'axi', 'aﬀect', 'aﬀord', 'aﬃn', 'back', 'background', 'backpropag', 'backward', 'bad', 'badli', 'bag', 'balanc', 'ball', 'band', 'bandit', 'bandwidth', 'bank', 'bar', 'bartlett', 'base', 'baselin', 'basi', 'basic', 'basis__functions', 'batch', 'bay', 'bayesian', 'bear', 'beat', 'begin', 'behav', 'behavior', 'behaviour', 'belief', 'believ', 'bellman', 'belong', 'benchmark', 'beneﬁci', 'beneﬁt', 'bengio', 'ber', 'bernoulli', 'beta', 'bia', 'bias', 'big', 'billion', 'bin', 'binari', 'binary__classiﬁcation', 'binomi', 'biolog', 'bipartit', 'bird', 'bit', 'black', 'block', 'blue', 'blur', 'bodi', 'bold', 'boldfac', 'boltzmann', 'book', 'boost', 'bootstrap', 'borrow', 'bottleneck', 'bottom', 'bound', 'boundari', 'box', 'bracket', 'brain', 'branch', 'break', 'breakthrough', 'bregman', 'breviti', 'bridg', 'brieﬂi', 'bring', 'broad', 'broader', 'broadli', 'broken', 'budget', 'build', 'built', 'burden', 'burn-in', 'bypass', 'calcul', 'calibr', 'call', 'cancel', 'cancer', 'candid', 'canon', 'capabl', 'capac', 'capit', 'caption', 'captur', 'car', 'cardin', 'care', 'carri', 'cascad', 'case', 'cast', 'cat', 'categor', 'categori', 'caus', 'causal', 'cell', 'center', 'central', 'certainti', 'chain', 'challeng', 'chanc', 'chang', 'channel', 'chapter', 'charact', 'character', 'characterist', 'cheap', 'check', 'chemic', 'chen', 'child', 'children', 'china', 'choic', 'choleski', 'choos', 'chose', 'chosen', 'cifar-10', 'cifar-100', 'circl', 'circuit', 'circumv', 'citi', 'claim', 'clarifi', 'clariti', 'class', 'classic', 'classifi', 'classiﬁ', 'classiﬁc', 'clean', 'clear', 'click', 'clip', 'cliqu', 'clock', 'close', 'closed-form', 'closely__related', 'closer', 'cl ...

# %%
# Create the index for each vocab.
vocab_serial = {}
index = 0
for i in vocab_sorted:
    vocab_serial[i] = index
    index += 1
len(vocab_serial)
# Out:
# 2546

# %%
# Set the output format
vocab_output = ''
for k,v in vocab_serial.items():
    vocab_output = vocab_output + k + ':' + str(v)
    vocab_output += '\n'

print(vocab_output)
# Out:
# AUC:0
# BFGS:1
# Bayesian__approach:2
# Beach__CA:3
# CAREER:4
# CCF:5
# CDF:6
# CIFAR:7
# CNN:8
# CPU:9
# DARPA:10
# DKL:11
# ERC:12
# Experiments__We:13
# FP7:14
# Figure__The:15
# Fisher__information:16
# GHz:17
# GPU:18
# GPUs:19
# GPs:20
# Gaussian__process:21
# Gibbs__sampler:22
# Gibbs__sampling:23
# HMM:24
# HMMs:25
# III:26
# IIS:27
# ImageNet:28
# In__order:29
# KL__divergence:30
# LASSO:31
# LDA:32
# LSTM:33
# LeCun:34
# MAP:35
# MATLAB:36
# MCMC:37
# MDP:38
# MDPs:39
# MLE:40
# MLP:41
# MNIST:42
# MSE:43
# Markov__chain:44
# Monte__Carlo:45
# NIPS:46
# NIPS__Barcelona:47
# NIPS__Long:48
# NSF:49
# NVIDIA:50
# Neural__Information:51
# ONR:52
# PAC:53
# PCA:54
# Processing__Systems:55
# RAM:56
# RBF:57
# RGB:58
# RHS:59
# RKHS:60
# RMSE:61
# RNN:62
# ROC:63
# ReLU:64
# SDP:65
# SGD:66
# SVD:67
# SVM:68
# SVMs:69
# This__work:70
# UCB:71
# UCI:72
# USA:73
# W911NF:74
# abbrevi:75
# abil:76
# absenc:77
# absent:78
# absolut:79
# abstract:80
# abund:81
# abus:82
# acc:83
# acceler:84
# accept:85
# access:86
# accomplish:87
# accord:88
# account:89
# accumul:90
# accur:91
# accuraci:92
# achiev:93
# acknowledg:94
# acquir:95
# acquisit:96
# act:97
# action:98
# activ:99
# active__learning:100
# actual:101
# acycl:102
# adam:103
# adapt:104
# add:105
# addit:106
# address:107
# adequ:108
# adjac:109
# adjust:110
# admit:111
# adopt:112
# advanc:113
# advantag:114
# adversari:115
# advertis:116
# advoc:117
# aforement:118
# age:119
# agenc:120
# agent:121
# agent?:122
# aggreg:123
# agre:124
# agreement:125
# aid:126
# aij:127
# aim:128
# akin:129
# albeit:130
# alg:131
# algebra:132
# algorithm:133
# algorithm?:134
# align:135
# allevi:136
# alloc:137
# allow:138
# alphabet:139
# alter:140
# altern:141
# altogeth:142
# amazon:143
# ambient:144
# ambigu:145
# amen:146
# amount:147
# amplitud:148
# analog:149
# analogu:150
# analys:151
# analysi:152
# analyt:153
# analyz:154
# ancestor:155
# angl:156
# anim:157
# anneal:158
# annot:159
# anonym:160
# answer:161
# anticip:162
# appar:163
# appeal:164
# appear:165
# appendix:166
# appli:167
# applic:168
# approach:169
# appropri:170
# approxim:171
# approximate__inference:172
# arbitrari:173
# arbitrarili:174
# architectur:175
# archiv:176
# area:177
# arg:178
# arg__min:179
# argmax:180
# argmin:181
# argu:182
# arguabl:183
# argument:184
# aris:185
# arm:186
# arrang:187
# array:188
# arriv:189
# arrow:190
# art:191
# articl:192
# artifact:193
# artiﬁci:194
# ascent:195
# ask:196
# aspect:197
# assert:198
# assess:199
# assign:200
# associ:201
# assum:202
# assumpt:203
# assur:204
# asymmetr:205
# asymptot:206
# asynchron:207
# at?1:208
# atom:209
# attach:210
# attain:211
# attempt:212
# attent:213
# attract:214
# attribut:215
# augment:216
# author:217
# autoencod:218
# autom:219
# automat:220
# auxiliari:221
# avail:222
# avenu:223
# averag:224
# avg:225
# avoid:226
# awar:227
# award:228
# axe:229
# axi:230
# aﬀect:231
# aﬀord:232
# aﬃn:233
# back:234
# background:235
# backpropag:236
# backward:237
# bad:238
# badli:239
# bag:240
# balanc:241
# ball:242
# band:243
# bandit:244
# bandwidth:245
# bank:246
# bar:247
# bartlett:248
# base:249
# baselin:250
# basi:251
# basic:252
# basis__functions:253
# batch:254
# bay:255
# bayesian:256
# bear:257
# beat:258
# begin:259
# behav:260
# behavior:261
# behaviour:262
# belief:263
# believ:264
# bellman:265
# belong:266
# benchmark:267
# beneﬁci:268
# beneﬁt:269
# bengio:270
# ber:271
# bernoulli:272
# beta:273
# bia:274
# bias:275
# big:276
# billion:277
# bin:278
# binari:279
# binary__classiﬁcation:280
# binomi:281
# biolog:282
# bipartit:283
# bird:284
# bit:285
# black:286
# block:287
# blue:288
# blur:289
# bodi:290
# bold:291
# boldfac:292
# boltzmann:293
# book:294
# boost:295
# bootstrap:296
# borrow:297
# bottleneck:298
# bottom:299
# bound:300
# boundari:301
# box:302
# bracket:303
# brain:304
# branch:305
# break:306
# breakthrough:307
# bregman:308
# breviti:309
# bridg:310
# brieﬂi:311
# bring:312
# broad:313
# broader:314
# broadli:315
# broken:316
# budget:317
# build:318
# built:319
# burden:320
# burn-in:321
# bypass:322
# calcul:323
# calibr:324
# call:325
# cancel:326
# cancer:327
# candid:328
# canon:329
# capabl:330
# capac:331
# capit:332
# caption:333
# captur:334
# car:335
# cardin:336
# care:337
# carri:338
# cascad:339
# case:340
# cast:341
# cat:342
# categor:343
# categori:344
# caus:345
# causal:346
# cell:347
# center:348
# central:349
# certainti:350
# chain:351
# challeng:352
# chanc:353
# chang:354
# channel:355
# chapter:356
# charact:357
# character:358
# characterist:359
# cheap:360
# check:361
# chemic:362
# chen:363
# child:364
# children:365
# china:366
# choic:367
# choleski:368
# choos:369
# chose:370
# chosen:371
# cifar-10:372
# cifar-100:373
# circl:374
# circuit:375
# circumv:376
# citi:377
# claim:378
# clarifi:379
# clariti:380
# class:381
# classic:382
# classifi:383
# classiﬁ:384
# classiﬁc:385
# clean:386
# clear:387
# click:388
# clip:389
# cliqu:390
# clock:391
# close:392
# closed-form:393
# closely__related:394
# closer:395
# closest:396
# cloud:397
# cluster:398
# code:399
# coeﬃcient:400
# coher:401
# coin:402
# coincid:403
# collabor:404
# collaps:405
# collect:406
# color:407
# column:408
# combin:409
# combinatori:410
# come:411
# comment:412
# commiss:413
# common:414
# commonli:415
# commun:416
# compact:417
# compar:418
# comparison:419
# compat:420
# compens:421
# compet:422
# competit:423
# competitor:424
# compil:425
# complement:426
# complementari:427
# complet:428
# complex:429
# complic:430
# compon:431
# compos:432
# composit:433
# comprehens:434
# compress:435
# compris:436
# compromis:437
# comput:438
# computational__complexity:439
# computational__cost:440
# computer__vision:441
# concaten:442
# concav:443
# conceiv:444
# concentr:445
# concept:446
# conceptu:447
# concern:448
# conclud:449
# conclus:450
# concret:451
# condit:452
# conditional__probability:453
# conduct:454
# cone:455
# confer:456
# conform:457
# confus:458
# conjectur:459
# conjug:460
# conjunct:461
# connect:462
# consecut:463
# consequ:464
# conserv:465
# consid:466
# consider:467
# consist:468
# const:469
# constant:470
# constitut:471
# constrain:472
# constraint:473
# construct:474
# consum:475
# consumpt:476
# contain:477
# content:478
# context:479
# contextu:480
# continu:481
# contour:482
# contract:483
# contradict:484
# contrari:485
# contrast:486
# contribut:487
# control:488
# conv:489
# conveni:490
# convent:491
# converg:492
# convergence__rate:493
# convers:494
# convert:495
# convex:496
# convex__function:497
# convex__functions:498
# convex__optimization:499
# convey:500
# convolut:501
# convolv:502
# conﬁdenc:503
# conﬁdent:504
# conﬁgur:505
# conﬁrm:506
# conﬂict:507
# coordin:508
# cope:509
# copi:510
# core:511
# corner:512
# corollari:513
# corpor:514
# corpu:515
# corr:516
# correct:517
# correctli:518
# correl:519
# correspond:520
# correspondingli:521
# corrupt:522
# cortex:523
# cortic:524
# cosin:525
# cost:526
# cost__function:527
# costli:528
# council:529
# count:530
# counter:531
# counterpart:532
# coupl:533
# covari:534
# covariance__matrix:535
# cover:536
# coverag:537
# creat:538
# criteria:539
# criterion:540
# critic:541
# crop:542
# cross:543
# cross-entropi:544
# cross-valid:545
# crucial:546
# cubic:547
# cue:548
# cumul:549
# current:550
# curv:551
# curvatur:552
# custom:553
# cut:554
# cycl:555
# dark:556
# dash:557
# data:558
# data-depend:559
# data-driven:560
# data__distribution:561
# data__point:562
# data__points:563
# data__set:564
# data__sets:565
# databas:566
# datapoint:567
# dataset:568
# date:569
# david:570
# day:571
# de?n:572
# de?nit:573
# deal:574
# dealt:575
# decad:576
# decay:577
# decid:578
# decis:579
# declar:580
# decod:581
# decompos:582
# decomposit:583
# decoupl:584
# decreas:585
# deduc:586
# deep:587
# deep__network:588
# deep__networks:589
# deeper:590
# def:591
# default:592
# defer:593
# degener:594
# degrad:595
# degre:596
# delay:597
# delic:598
# delta:599
# demand:600
# demonstr:601
# denois:602
# denomin:603
# denot:604
# dens:605
# densiti:606
# depart:607
# depend:608
# depict:609
# deploy:610
# depth:611
# deriv:612
# descend:613
# descent:614
# describ:615
# descript:616
# descriptor:617
# design:618
# desir:619
# det:620
# detail:621
# detect:622
# detector:623
# deterior:624
# determin:625
# determinist:626
# develop:627
# deviat:628
# devic:629
# devis:630
# devot:631
# deﬁcienc:632
# deﬁn:633
# deﬁnit:634
# diabet:635
# diag:636
# diagnosi:637
# diagon:638
# diagram:639
# diamet:640
# dictat:641
# dictionari:642
# digit:643
# dim:644
# dimens:645
# dimension:646
# diminish:647
# dir:648
# dirac:649
# direct:650
# directli:651
# dirichlet:652
# disadvantag:653
# disagr:654
# disagre:655
# discard:656
# discontinu:657
# discount:658
# discov:659
# discoveri:660
# discrep:661
# discret:662
# discrimin:663
# discuss:664
# diseas:665
# disjoint:666
# disk:667
# display:668
# dissimilar:669
# dist:670
# distanc:671
# distant:672
# distinct:673
# distinguish:674
# distort:675
# distribut:676
# diverg:677
# divers:678
# divid:679
# divis:680
# diﬀerent__values:681
# diﬀerenti:682
# diﬀus:683
# diﬃcult:684
# diﬃculti:685
# document:686
# doesn?t:687
# dog:688
# domain:689
# domin:690
# don?t:691
# donat:692
# dot:693
# doubl:694
# download:695
# dramat:696
# drastic:697
# draw:698
# drawback:699
# drawn:700
# drift:701
# drive:702
# driven:703
# drop:704
# dropout:705
# dual:706
# dualiti:707
# due:708
# durat:709
# dynam:710
# earli:711
# earlier:712
# eas:713
# easi:714
# easier:715
# easili:716
# econom:717
# edg:718
# educ:719
# eigenvalu:720
# eigenvector:721
# elabor:722
# eld:723
# elect:724
# electr:725
# electron:726
# eleg:727
# element:728
# element-wis:729
# elementari:730
# elimin:731
# ellipt:732
# elucid:733
# emb:734
# embed:735
# emerg:736
# emit:737
# emphas:738
# emphasi:739
# empir:740
# employ:741
# empti:742
# emul:743
# enabl:744
# encod:745
# encoder-decod:746
# encompass:747
# encount:748
# encourag:749
# end:750
# end-to:751
# endow:752
# energi:753
# enforc:754
# engin:755
# english:756
# enhanc:757
# enjoy:758
# ensembl:759
# ensur:760
# entail:761
# enter:762
# entir:763
# entiti:764
# entri:765
# entropi:766
# enumer:767
# envelop:768
# environ:769
# episod:770
# epoch:771
# eqn:772
# equal:773
# equat:774
# equilibrium:775
# equip:776
# equival:777
# erron:778
# error:779
# error__rate:780
# essenti:781
# establish:782
# estim:783
# euclidean:784
# european:785
# evalu:786
# evenli:787
# event:788
# eventu:789
# evid:790
# evolut:791
# evolutionari:792
# evolv:793
# exact:794
# examin:795
# exampl:796
# exce:797
# exceed:798
# excel:799
# except:800
# excess:801
# exchang:802
# excit:803
# exclud:804
# exclus:805
# execut:806
# exhaust:807
# exhibit:808
# exibl:809
# exist:810
# exp:811
# expand:812
# expans:813
# expect:814
# expectation-maxim:815
# expected__number:816
# expens:817
# experi:818
# experiment:819
# experimental__results:820
# expert:821
# explain:822
# explan:823
# explicit:824
# explicitli:825
# exploit:826
# explor:827
# expon:828
# exponenti:829
# exponential__family:830
# expos:831
# exposit:832
# exposur:833
# express:834
# extend:835
# extens:836
# extent:837
# extern:838
# extra:839
# extract:840
# extrapol:841
# extrem:842
# eye:843
# eﬀect:844
# eﬀort:845
# eﬃcaci:846
# eﬃcienc:847
# eﬃcient:848
# face:849
# facebook:850
# facilit:851
# fact:852
# factor:853
# factori:854
# faculti:855
# fail:856
# failur:857
# fair:858
# fairli:859
# faith:860
# fall:861
# fals:862
# famili:863
# familiar:864
# fashion:865
# fast:866
# faster:867
# fastest:868
# favor:869
# favour:870
# feasibl:871
# featur:872
# feature__space:873
# feature__vector:874
# fed:875
# feed:876
# feed-forward:877
# feedback:878
# feedforward:879
# fellowship:880
# fewer:881
# fig:882
# fig__shows:883
# figur:884
# figure__shows:885
# filter:886
# final:887
# find:888
# firstli:889
# fix:890
# focu:891
# focus:892
# fold:893
# follow:894
# forc:895
# forget:896
# form:897
# formal:898
# format:899
# formul:900
# formula:901
# fortun:902
# forward:903
# forward-backward:904
# found:905
# foundat:906
# fourier:907
# fourth:908
# fraction:909
# frame:910
# framework:911
# free:912
# freedom:913
# freez:914
# frequenc:915
# frequent:916
# frobeniu:917
# front:918
# fruit:919
# full:920
# fulli:921
# fully-connect:922
# fulﬁll:923
# function:924
# fund:925
# fundament:926
# futur:927
# future__work:928
# gabor:929
# gain:930
# game:931
# gamma:932
# gap:933
# gate:934
# gather:935
# gaussian:936
# gave:937
# gene:938
# generalis:939
# generative__model:940
# genet:941
# geometr:942
# geometri:943
# german:944
# gibb:945
# github:946
# give:947
# glanc:948
# global:949
# goal:950
# good:951
# googl:952
# govern:953
# grace:954
# gradient:955
# gradient__descent:956
# gradient__method:957
# gradual:958
# gram:959
# grant:960
# graph:961
# graphic:962
# graphical__model:963
# graphical__models:964
# grate:965
# gray:966
# great:967
# greater:968
# greatest:969
# greatli:970
# greedi:971
# greedili:972
# green:973
# grey:974
# grid:975
# ground:976
# ground-truth:977
# ground__truth:978
# group:979
# grow:980
# growth:981
# guarante:982
# guess:983
# guid:984
# guidanc:985
# gure:986
# half:987
# halt:988
# ham:989
# hand:990
# handl:991
# handwritten:992
# happen:993
# hard:994
# harder:995
# hardwar:996
# hash:997
# head:998
# health:999
# heart:1000
# heavi:1001
# heavili:1002
# height:1003
# held:1004
# held-out:1005
# help:1006
# henceforth:1007
# hessian:1008
# heterogen:1009
# heurist:1010
# hidden:1011
# hidden__layer:1012
# hidden__units:1013
# hide:1014
# hierarch:1015
# hierarchi:1016
# hierarchical__clustering:1017
# high:1018
# high-dimension:1019
# high-level:1020
# high-qual:1021
# high__dimensional:1022
# high__probability:1023
# higher:1024
# higher-ord:1025
# highest:1026
# highli:1027
# highlight:1028
# hilbert:1029
# hinder:1030
# hindsight:1031
# hing:1032
# hint:1033
# hinton:1034
# histogram:1035
# histor:1036
# histori:1037
# history-depend:1038
# hit:1039
# hoeﬀding?:1040
# hold:1041
# homogen:1042
# hope:1043
# horizon:1044
# horizont:1045
# hour:1046
# hous:1047
# ht?1:1048
# html:1049
# http:1050
# huge:1051
# hull:1052
# human:1053
# hundr:1054
# hurt:1055
# hybrid:1056
# hyper-paramet:1057
# hyperparamet:1058
# hyperplan:1059
# hypothes:1060
# hypothesi:1061
# hypothet:1062
# idea:1063
# ideal:1064
# ident:1065
# identifi:1066
# identiﬁ:1067
# identiﬁc:1068
# ignor:1069
# iid:1070
# iii:1071
# illumin:1072
# illustr:1073
# imag:1074
# imagenet:1075
# imagin:1076
# imit:1077
# immedi:1078
# impact:1079
# imperfect:1080
# implement:1081
# impli:1082
# implic:1083
# implicit:1084
# implicitli:1085
# import:1086
# importantli:1087
# impos:1088
# imposs:1089
# impract:1090
# impress:1091
# improv:1092
# inaccur:1093
# inact:1094
# incid:1095
# includ:1096
# inclus:1097
# incom:1098
# incomplet:1099
# inconsist:1100
# incorpor:1101
# incorrect:1102
# increas:1103
# increasingli:1104
# increment:1105
# incur:1106
# independ:1107
# index:1108
# indeﬁnit:1109
# indic:1110
# indirectli:1111
# indistinguish:1112
# individu:1113
# induc:1114
# induct:1115
# industri:1116
# inequ:1117
# inevit:1118
# inexact:1119
# ineﬃci:1120
# inf:1121
# infeas:1122
# infer:1123
# inform:1124
# information-theoret:1125
# informationtheoret:1126
# ing:1127
# ingredi:1128
# inher:1129
# inherit:1130
# inhibit:1131
# inhomogen:1132
# initi:1133
# initialis:1134
# inject:1135
# innov:1136
# input:1137
# input-output:1138
# input__space:1139
# insert:1140
# insid:1141
# insight:1142
# inspect:1143
# inspir:1144
# instanc:1145
# instant:1146
# instantan:1147
# instanti:1148
# institut:1149
# instruct:1150
# instrument:1151
# integ:1152
# integr:1153
# intel:1154
# intellig:1155
# intend:1156
# intens:1157
# intent:1158
# interact:1159
# interchang:1160
# interest:1161
# interestingli:1162
# interior:1163
# intermedi:1164
# intern:1165
# interpol:1166
# interpret:1167
# intersect:1168
# interv:1169
# intract:1170
# intrins:1171
# introduc:1172
# introduct:1173
# intuit:1174
# invari:1175
# invers:1176
# invert:1177
# investig:1178
# involv:1179
# inﬁnit:1180
# inﬁniti:1181
# inﬂuenc:1182
# inﬂuenti:1183
# irrelev:1184
# isol:1185
# isotrop:1186
# israel:1187
# issu:1188
# it?:1189
# item:1190
# iter:1191
# ith:1192
# jensen?:1193
# job:1194
# join:1195
# joint:1196
# jointli:1197
# jth:1198
# judg:1199
# judgment:1200
# jump:1201
# justifi:1202
# justiﬁ:1203
# justiﬁc:1204
# k22:1205
# k2f:1206
# keep:1207
# kernel:1208
# key:1209
# kind:1210
# kinet:1211
# kl-diverg:1212
# knew:1213
# know:1214
# knowledg:1215
# kth:1216
# kullback-leibl:1217
# kxi:1218
# kxk:1219
# kxk1:1220
# label:1221
# labeled__data:1222
# laboratori:1223
# lack:1224
# lagrangian:1225
# languag:1226
# laplac:1227
# laplacian:1228
# larg:1229
# large-scal:1230
# large__datasets:1231
# large__number:1232
# larger:1233
# largest:1234
# lasso:1235
# lastli:1236
# latenc:1237
# latent:1238
# latent__variable:1239
# latent__variables:1240
# latest:1241
# law:1242
# layer:1243
# lead:1244
# leaf:1245
# learn:1246
# learnabl:1247
# learner:1248
# learning__algorithm:1249
# learning__algorithms:1250
# learning__methods:1251
# learning__problem:1252
# learning__rate:1253
# learnt:1254
# least-squar:1255
# leav:1256
# lebesgu:1257
# led:1258
# lee:1259
# left:1260
# left-hand:1261
# lemma:1262
# lend:1263
# length:1264
# let:1265
# let?:1266
# letter:1267
# level:1268
# leverag:1269
# librari:1270
# lie:1271
# life:1272
# light:1273
# likelihood:1274
# likewis:1275
# lim:1276
# limit:1277
# lin:1278
# line:1279
# linear:1280
# linear__combination:1281
# linear__model:1282
# linearli:1283
# link:1284
# link__function:1285
# linkag:1286
# lipschitz:1287
# list:1288
# literatur:1289
# live:1290
# load:1291
# local:1292
# locat:1293
# log:1294
# log-likelihood:1295
# log-prob:1296
# log2:1297
# log__exp:1298
# log__log:1299
# logarithm:1300
# logic:1301
# logist:1302
# logistic__regression:1303
# loglikelihood:1304
# long:1305
# long-rang:1306
# long-term:1307
# longer:1308
# loop:1309
# loos:1310
# lose:1311
# loss:1312
# loss__function:1313
# loss__functions:1314
# lost:1315
# lot:1316
# low:1317
# low-dimension:1318
# low-level:1319
# low-rank:1320
# low__dimensional:1321
# lower:1322
# lower__bound:1323
# lower__bounds:1324
# lowest:1325
# lowrank:1326
# lter:1327
# ltere:1328
# lumin:1329
# machin:1330
# machine__learning:1331
# made:1332
# magnitud:1333
# main:1334
# main__result:1335
# maintain:1336
# major:1337
# make:1338
# manag:1339
# manifold:1340
# manipul:1341
# manner:1342
# manual:1343
# map:1344
# margin:1345
# marginal__likelihood:1346
# mark:1347
# marker:1348
# market:1349
# markov:1350
# mask:1351
# mass:1352
# massiv:1353
# master:1354
# match:1355
# materi:1356
# mathemat:1357
# matlab:1358
# matric:1359
# matrix:1360
# matrix__completion:1361
# matter:1362
# max:1363
# max-pool:1364
# maxi:1365
# maxim:1366
# maxima:1367
# maximis:1368
# maximum:1369
# maximum__likelihood:1370
# maxj:1371
# maxt:1372
# mean:1373
# mean-ﬁeld:1374
# meaning:1375
# meant:1376
# measur:1377
# mechan:1378
# median:1379
# medic:1380
# medium:1381
# meet:1382
# member:1383
# membership:1384
# memori:1385
# ment:1386
# mention:1387
# merg:1388
# merit:1389
# messag:1390
# message-pass:1391
# met:1392
# method:1393
# methodolog:1394
# metric:1395
# metric__space:1396
# metropolis-hast:1397
# microsoft:1398
# middl:1399
# mild:1400
# million:1401
# mimic:1402
# min:1403
# mind:1404
# mini:1405
# mini-batch:1406
# minibatch:1407
# minim:1408
# minima:1409
# minimax:1410
# minimis:1411
# minimum:1412
# minor:1413
# minu:1414
# minut:1415
# minw:1416
# mirror:1417
# mismatch:1418
# miss:1419
# mistak:1420
# mitig:1421
# mix:1422
# mixtur:1423
# mixture__model:1424
# mod:1425
# mode:1426
# model:1427
# model-bas:1428
# model?:1429
# model__parameters:1430
# moder:1431
# modern:1432
# modifi:1433
# modiﬁ:1434
# modiﬁc:1435
# modul:1436
# modular:1437
# modulu:1438
# moment:1439
# momentum:1440
# monitor:1441
# monoton:1442
# month:1443
# motion:1444
# motiv:1445
# move:1446
# movement:1447
# movi:1448
# multi-arm:1449
# multi-class:1450
# multi-dimension:1451
# multi-task:1452
# multiclass:1453
# multidimension:1454
# multilay:1455
# multimod:1456
# multinomi:1457
# multipl:1458
# multipli:1459
# multiset:1460
# multivari:1461
# mutual:1462
# na?v:1463
# naiv:1464
# nal:1465
# nalli:1466
# name:1467
# nancial:1468
# narrow:1469
# nation:1470
# natur:1471
# natural__images:1472
# nding:1473
# ne-grain:1474
# ne-tun:1475
# near-optim:1476
# nearbi:1477
# nearest:1478
# necessarili:1479
# need:1480
# neg:1481
# neglect:1482
# neglig:1483
# neighbor:1484
# neighborhood:1485
# neighbour:1486
# ner:1487
# nest:1488
# net:1489
# network:1490
# network?:1491
# neural:1492
# neural__network:1493
# neural__networks:1494
# neuron:1495
# neuron?:1496
# neurosci:1497
# neutral:1498
# new:1499
# newli:1500
# news:1501
# nice:1502
# nish:1503
# nite:1504
# node:1505
# nois:1506
# noiseless:1507
# noisi:1508
# non-convex:1509
# non-decreas:1510
# non-diﬀerenti:1511
# non-empti:1512
# non-gaussian:1513
# non-increas:1514
# non-linear:1515
# non-neg:1516
# non-optim:1517
# non-overlap:1518
# non-parametr:1519
# non-posit:1520
# non-smooth:1521
# non-stationari:1522
# non-trivi:1523
# non-uniform:1524
# non-zero:1525
# nonconvex:1526
# nonetheless:1527
# nonlinear:1528
# nonneg:1529
# nonparametr:1530
# nontrivi:1531
# nonzero:1532
# norm:1533
# normal:1534
# notabl:1535
# notat:1536
# note:1537
# notic:1538
# notion:1539
# notori:1540
# np-hard:1541
# nth:1542
# nuclear:1543
# null:1544
# number:1545
# numer:1546
# obey:1547
# object:1548
# objective__function:1549
# observ:1550
# obstacl:1551
# obtain:1552
# obviou:1553
# occasion:1554
# occupi:1555
# occur:1556
# occurr:1557
# odd:1558
# of__the:1559
# older:1560
# omit:1561
# one-dimension:1562
# one-hot:1563
# one-step:1564
# one-to:1565
# onlin:1566
# online__learning:1567
# open:1568
# oper:1569
# opinion:1570
# opportun:1571
# oppos:1572
# opposit:1573
# optim:1574
# optima:1575
# optimal__policy:1576
# optimal__solution:1577
# optimis:1578
# optimist:1579
# optimization__problem:1580
# optimization__problems:1581
# optimum:1582
# option:1583
# oracl:1584
# orang:1585
# order:1586
# ordin:1587
# ordinari:1588
# org:1589
# organ:1590
# orient:1591
# origin:1592
# orthogon:1593
# orthonorm:1594
# out-of:1595
# outcom:1596
# outer:1597
# outlier:1598
# outlin:1599
# outperform:1600
# output:1601
# over-ﬁt:1602
# overcom:1603
# overestim:1604
# overhead:1605
# overlap:1606
# overli:1607
# overview:1608
# overﬁt:1609
# oﬀ-diagon:1610
# oﬀer:1611
# oﬀset:1612
# oﬃc:1613
# oﬄin:1614
# packag:1615
# page:1616
# pair:1617
# pairwis:1618
# panel:1619
# paper:1620
# paradigm:1621
# paragraph:1622
# parallel:1623
# paralleliz:1624
# paramet:1625
# parameter:1626
# parametr:1627
# parent:1628
# part:1629
# partial:1630
# particip:1631
# particl:1632
# partit:1633
# partli:1634
# pass:1635
# passiv:1636
# past:1637
# patch:1638
# path:1639
# patholog:1640
# pathway:1641
# patient:1642
# pattern:1643
# pay:1644
# peak:1645
# penal:1646
# penalti:1647
# peopl:1648
# perceiv:1649
# percent:1650
# percentag:1651
# percept:1652
# perceptron:1653
# perceptu:1654
# perfect:1655
# perfectli:1656
# perform:1657
# period:1658
# permit:1659
# permut:1660
# persist:1661
# person:1662
# perspect:1663
# pertain:1664
# perturb:1665
# phase:1666
# phenomena:1667
# phenomenon:1668
# physic:1669
# physiolog:1670
# pick:1671
# pictur:1672
# piec:1673
# piecewis:1674
# pipelin:1675
# pixel:1676
# place:1677
# plan:1678
# plane:1679
# plant:1680
# platform:1681
# plausibl:1682
# play:1683
# player:1684
# player?:1685
# ple:1686
# plot:1687
# plug:1688
# point:1689
# pointwis:1690
# poisson:1691
# poli:1692
# polici:1693
# polynomi:1694
# pool:1695
# poor:1696
# poorli:1697
# popul:1698
# popular:1699
# portion:1700
# pose:1701
# posit:1702
# positive-deﬁnit:1703
# possess:1704
# possibl:1705
# post:1706
# post-process:1707
# posterior:1708
# posterior__distribution:1709
# posteriori:1710
# postpon:1711
# potenti:1712
# power:1713
# power-law:1714
# practic:1715
# practition:1716
# pre-comput:1717
# pre-deﬁn:1718
# pre-process:1719
# pre-train:1720
# preced:1721
# precis:1722
# predeﬁn:1723
# predict:1724
# predictor:1725
# prefer:1726
# preferenti:1727
# preliminari:1728
# prepar:1729
# preprocess:1730
# prescrib:1731
# presenc:1732
# present:1733
# preserv:1734
# pretrain:1735
# preval:1736
# prevent:1737
# previou:1738
# previous:1739
# previous__section:1740
# previous__work:1741
# preﬁx:1742
# price:1743
# primal:1744
# primari:1745
# primarili:1746
# primit:1747
# princip:1748
# principl:1749
# prior:1750
# prior__distribution:1751
# priori:1752
# privat:1753
# prob:1754
# probabilist:1755
# probability__distribution:1756
# probability__distributions:1757
# probability__mass:1758
# probabl:1759
# probe:1760
# problem:1761
# problemat:1762
# proce:1763
# procedur:1764
# proceed:1765
# process:1766
# processor:1767
# produc:1768
# product:1769
# program:1770
# progress:1771
# prohibit:1772
# project:1773
# promin:1774
# promis:1775
# promot:1776
# prone:1777
# pronounc:1778
# proof:1779
# propag:1780
# proper:1781
# properli:1782
# properti:1783
# proport:1784
# propos:1785
# proposed__algorithm:1786
# proposed__method:1787
# proposed__model:1788
# proposit:1789
# protein:1790
# protocol:1791
# prototyp:1792
# provabl:1793
# prove:1794
# proven:1795
# provid:1796
# proxi:1797
# proxim:1798
# proﬁl:1799
# prune:1800
# pseudo-cod:1801
# pseudocod:1802
# public:1803
# publicli:1804
# publish:1805
# pull:1806
# purchas:1807
# pure:1808
# purpos:1809
# pursu:1810
# pursuit:1811
# push:1812
# put:1813
# quadrat:1814
# qualit:1815
# qualiti:1816
# quantifi:1817
# quantil:1818
# quantit:1819
# quantiti:1820
# quantiz:1821
# quantiﬁ:1822
# queri:1823
# question:1824
# quickli:1825
# rademach:1826
# radial:1827
# radiu:1828
# rais:1829
# ran:1830
# random:1831
# random__variable:1832
# random__variables:1833
# randomli:1834
# rang:1835
# rank:1836
# rank-1:1837
# rapid:1838
# rapidli:1839
# rare:1840
# rate:1841
# ratio:1842
# rational:1843
# raw:1844
# rd?d:1845
# re-train:1846
# reach:1847
# read:1848
# reader:1849
# readi:1850
# readili:1851
# real:1852
# real-valu:1853
# real-world:1854
# real__data:1855
# real__world:1856
# realist:1857
# realiz:1858
# realworld:1859
# reason:1860
# recal:1861
# receiv:1862
# recent:1863
# recent__work:1864
# receptive__eld:1865
# receptive__elds:1866
# recogn:1867
# recognit:1868
# recommend:1869
# reconstruct:1870
# record:1871
# recov:1872
# recoveri:1873
# rectifi:1874
# rectiﬁ:1875
# recurr:1876
# recurs:1877
# red:1878
# reduc:1879
# reduct:1880
# redund:1881
# refer:1882
# reformul:1883
# regard:1884
# regim:1885
# region:1886
# regress:1887
# regressor:1888
# regret:1889
# regret__bound:1890
# regul:1891
# regular:1892
# reinforc:1893
# reinforcement__learning:1894
# reject:1895
# rel:1896
# relat:1897
# related__work:1898
# relationship:1899
# relax:1900
# releas:1901
# relev:1902
# reli:1903
# reliabl:1904
# remain:1905
# remaind:1906
# remark:1907
# rememb:1908
# reminisc:1909
# remov:1910
# render:1911
# repeat:1912
# repeatedli:1913
# repetit:1914
# replac:1915
# replic:1916
# report:1917
# repositori:1918
# repres:1919
# represent:1920
# reproduc:1921
# request:1922
# requir:1923
# resampl:1924
# rescal:1925
# research:1926
# resembl:1927
# reserv:1928
# reset:1929
# resid:1930
# residu:1931
# resiz:1932
# resolut:1933
# resolv:1934
# resort:1935
# resourc:1936
# resp:1937
# respect:1938
# respond:1939
# respons:1940
# rest:1941
# restart:1942
# restrict:1943
# retain:1944
# retriev:1945
# return:1946
# reus:1947
# reveal:1948
# revers:1949
# review:1950
# revisit:1951
# reward:1952
# reward__function:1953
# rewrit:1954
# rewritten:1955
# reﬁn:1956
# reﬁnement:1957
# reﬂect:1958
# rich:1959
# richer:1960
# ridg:1961
# right-hand:1962
# rigor:1963
# ring:1964
# rise:1965
# risk:1966
# robot:1967
# robust:1968
# role:1969
# roll:1970
# root:1971
# rotat:1972
# rough:1973
# roughli:1974
# round:1975
# rout:1976
# routin:1977
# row:1978
# rst-order:1979
# rst__step:1980
# rule:1981
# run:1982
# running__time:1983
# runtim:1984
# sacriﬁc:1985
# sake:1986
# sale:1987
# sampl:1988
# sample__complexity:1989
# sample__size:1990
# sampler:1991
# satisfactori:1992
# satisfi:1993
# satisﬁ:1994
# satur:1995
# save:1996
# scalabl:1997
# scalar:1998
# scale:1999
# scatter:2000
# scenario:2001
# scene:2002
# schedul:2003
# schemat:2004
# scheme:2005
# scienc:2006
# scientiﬁc:2007
# scope:2008
# score:2009
# scratch:2010
# script:2011
# search:2012
# sec:2013
# second:2014
# second-ord:2015
# section:2016
# seed:2017
# seek:2018
# seemingli:2019
# segment:2020
# select:2021
# sell:2022
# semant:2023
# semi-deﬁnit:2024
# semi-supervis:2025
# semi-supervised__learn:2026
# semideﬁnit:2027
# semin:2028
# send:2029
# sens:2030
# sensit:2031
# sensor:2032
# sensori:2033
# sentenc:2034
# separ:2035
# sequenc:2036
# sequenti:2037
# seri:2038
# serv:2039
# servic:2040
# set-up:2041
# setup:2042
# sever:2043
# shade:2044
# shallow:2045
# shape:2046
# share:2047
# sharp:2048
# sharper:2049
# shed:2050
# shift:2051
# short:2052
# shortcom:2053
# shorter:2054
# shortest:2055
# shorthand:2056
# shot:2057
# shown:2058
# shrink:2059
# shrinkag:2060
# shuﬄe:2061
# side:2062
# sigmoid:2063
# sign:2064
# signal:2065
# signiﬁc:2066
# signiﬁcantli:2067
# similar:2068
# similarli:2069
# simon:2070
# simpl:2071
# simpler:2072
# simplest:2073
# simplex:2074
# simpli:2075
# simplic:2076
# simplifi:2077
# simpliﬁ:2078
# simpliﬁc:2079
# simul:2080
# simultan:2081
# sin:2082
# singl:2083
# singular:2084
# singular__values:2085
# sit:2086
# site:2087
# situat:2088
# size:2089
# sketch:2090
# skip:2091
# slack:2092
# slice:2093
# slide:2094
# slight:2095
# slightli:2096
# slope:2097
# slow:2098
# slower:2099
# slowli:2100
# small:2101
# small__number:2102
# smaller:2103
# smallest:2104
# smooth:2105
# smoother:2106
# smoothli:2107
# so-cal:2108
# social:2109
# soft:2110
# softmax:2111
# softwar:2112
# sole:2113
# solid:2114
# solut:2115
# solv:2116
# solver:2117
# sophist:2118
# sort:2119
# sound:2120
# sourc:2121
# space:2122
# spain:2123
# span:2124
# spars:2125
# sparser:2126
# sparsiti:2127
# spatial:2128
# speak:2129
# speci:2130
# special:2131
# special__case:2132
# special__cases:2133
# speciﬁ:2134
# speciﬁc:2135
# spectral:2136
# spectrum:2137
# speech:2138
# speed:2139
# speed-up:2140
# speedup:2141
# spend:2142
# spent:2143
# sphere:2144
# spheric:2145
# spike:2146
# spirit:2147
# split:2148
# sport:2149
# spot:2150
# spread:2151
# spuriou:2152
# squar:2153
# squared__error:2154
# st__Conference:2155
# stabil:2156
# stabl:2157
# stack:2158
# stage:2159
# stand:2160
# standard:2161
# standard__deviation:2162
# stanford:2163
# star:2164
# start:2165
# state:2166
# state-act:2167
# state-of:2168
# state-of__the-art:2169
# state-ofth:2170
# state__space:2171
# statement:2172
# stateof-th:2173
# static:2174
# stationar:2175
# stationari:2176
# stationary__distribution:2177
# statist:2178
# stay:2179
# std:2180
# steadi:2181
# stem:2182
# step:2183
# step__size:2184
# stepsiz:2185
# stimul:2186
# stimuli:2187
# stimulu:2188
# stochast:2189
# stochastic__gradient:2190
# stop:2191
# storag:2192
# store:2193
# straightforward:2194
# straightforwardli:2195
# strategi:2196
# stream:2197
# strength:2198
# strengthen:2199
# strict:2200
# strictli:2201
# stride:2202
# strike:2203
# string:2204
# strong:2205
# stronger:2206
# strongli:2207
# strongly__convex:2208
# structur:2209
# stuck:2210
# student:2211
# studi:2212
# style:2213
# sub-optim:2214
# sub-sampl:2215
# subgradi:2216
# subgraph:2217
# subject:2218
# sublinear:2219
# submit:2220
# submodular:2221
# suboptim:2222
# subproblem:2223
# subsampl:2224
# subscript:2225
# subsect:2226
# subsequ:2227
# subset:2228
# subspac:2229
# substanti:2230
# substitut:2231
# subsum:2232
# subtl:2233
# subtract:2234
# subtre:2235
# succe:2236
# succeed:2237
# success:2238
# sufﬁcient:2239
# suggest:2240
# suit:2241
# suitabl:2242
# sum:2243
# summar:2244
# summari:2245
# summat:2246
# superior:2247
# supervis:2248
# supervised__learning:2249
# supplement:2250
# supplementari:2251
# supplementary__material:2252
# support:2253
# suppos:2254
# suppress:2255
# supremum:2256
# sure:2257
# surfac:2258
# surpris:2259
# surprisingli:2260
# surrog:2261
# survey:2262
# suscept:2263
# suﬀer:2264
# suﬃc:2265
# suﬃcient:2266
# swap:2267
# sweep:2268
# switch:2269
# symbol:2270
# symmetr:2271
# symmetri:2272
# synaps:2273
# synapt:2274
# synchron:2275
# synthes:2276
# synthesi:2277
# synthet:2278
# synthetic__data:2279
# system:2280
# systemat:2281
# tabl:2282
# tackl:2283
# tail:2284
# tailor:2285
# take:2286
# tanh:2287
# target:2288
# task:2289
# taylor:2290
# technic:2291
# techniqu:2292
# technolog:2293
# tell:2294
# temperatur:2295
# tempor:2296
# ten:2297
# tend:2298
# tendenc:2299
# tensor:2300
# term:2301
# termin:2302
# terminolog:2303
# test:2304
# test__set:2305
# test__time:2306
# text:2307
# textur:2308
# theme:2309
# theorem:2310
# theoret:2311
# theoretical__analysis:2312
# theori:2313
# thing:2314
# thm:2315
# thought:2316
# thousand:2317
# threshold:2318
# tie:2319
# tight:2320
# tighter:2321
# time:2322
# time-vari:2323
# time__step:2324
# timescal:2325
# timestep:2326
# tion:2327
# today:2328
# token:2329
# toler:2330
# tool:2331
# top:2332
# top-down:2333
# topic:2334
# topolog:2335
# total:2336
# total__number:2337
# touch:2338
# toy:2339
# trace:2340
# track:2341
# tractabl:2342
# trade:2343
# trade-oﬀ:2344
# tradeoﬀ:2345
# tradit:2346
# train:2347
# training__data:2348
# training__examples:2349
# training__sample:2350
# training__set:2351
# training__time:2352
# trajectori:2353
# transfer:2354
# transform:2355
# transit:2356
# translat:2357
# transmit:2358
# transpar:2359
# transport:2360
# transpos:2361
# trap:2362
# travel:2363
# travers:2364
# treat:2365
# treatment:2366
# tree:2367
# trend:2368
# trial:2369
# triangl:2370
# trick:2371
# trigger:2372
# tripl:2373
# triplet:2374
# trivial:2375
# true:2376
# truncat:2377
# truth:2378
# tted:2379
# tting:2380
# tune:2381
# tupl:2382
# ture:2383
# turk:2384
# turn:2385
# two-dimension:2386
# two-stag:2387
# type:2388
# typic:2389
# ubiquit:2390
# uctuat:2391
# ultim:2392
# unabl:2393
# unbias:2394
# unbound:2395
# uncertain:2396
# uncertainti:2397
# unchang:2398
# unclear:2399
# unconstrain:2400
# uncorrel:2401
# underli:2402
# understand:2403
# understood:2404
# undesir:2405
# undirect:2406
# unfold:2407
# unifi:2408
# uniform:2409
# uniform__distribution:2410
# uniformli:2411
# uninform:2412
# union:2413
# uniqu:2414
# unit:2415
# univers:2416
# uniﬁ:2417
# unknown:2418
# unlabel:2419
# unlabeled__data:2420
# unlik:2421
# unlimit:2422
# unnecessari:2423
# unnorm:2424
# unobserv:2425
# unrealist:2426
# unrel:2427
# unseen:2428
# unstabl:2429
# unsupervis:2430
# updat:2431
# update__rule:2432
# upper:2433
# upper-bound:2434
# upper__bound:2435
# upward:2436
# usag:2437
# use:2438
# user:2439
# user?:2440
# usual:2441
# util:2442
# valid:2443
# validation__set:2444
# valu:2445
# valuabl:2446
# van:2447
# vanilla:2448
# vanish:2449
# vapnik:2450
# var:2451
# vari:2452
# variabl:2453
# varianc:2454
# variant:2455
# variat:2456
# variational__inference:2457
# varieti:2458
# vast:2459
# vector:2460
# veloc:2461
# verifi:2462
# veriﬁ:2463
# versa:2464
# version:2465
# versu:2466
# vertex:2467
# vertic:2468
# vice:2469
# video:2470
# view:2471
# viewpoint:2472
# violat:2473
# virtu:2474
# virtual:2475
# visibl:2476
# vision:2477
# visit:2478
# visual:2479
# vocabulari:2480
# volum:2481
# vote:2482
# wait:2483
# walk:2484
# wall:2485
# wang:2486
# wasserstein:2487
# wast:2488
# way:2489
# weak:2490
# weaker:2491
# weakli:2492
# web:2493
# websit:2494
# week:2495
# weight:2496
# weight__vector:2497
# well:2498
# well-deﬁn:2499
# well-known:2500
# well-studi:2501
# whilst:2502
# white:2503
# whiten:2504
# wide:2505
# wider:2506
# width:2507
# wij:2508
# win:2509
# window:2510
# wish:2511
# word:2512
# work:2513
# worker:2514
# world:2515
# wors:2516
# worsen:2517
# worst:2518
# worst-cas:2519
# worst__case:2520
# worth:2521
# write:2522
# written:2523
# wrong:2524
# www:2525
# x1__x2:2526
# x1__xn:2527
# xed:2528
# xed__point:2529
# xi__xi:2530
# xi__xj:2531
# xi__yi:2532
# xing:2533
# xk2:2534
# xt?1:2535
# xt__xt:2536
# xti:2537
# y1__y2:2538
# year:2539
# yi__xi:2540
# yield:2541
# zero:2542
# zero-mean:2543
# zhang:2544
# zi__yi:2545

# %%
# Output the vocabulary index file
def output_txt(astring):
    text_file = open('Group006_vocab.txt', 'w', encoding='utf-8')
    text_file.write(astring)
    text_file.close()

output_txt(vocab_output)

# %% [markdown]
# ### 4.8 Create the Sparse count vectors and output
#
# In this section, the sparse count vectors is created and then output as the txt file.

# %%
# Create the Sparse count vectors
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer
568:3,2543:9,2336:1,836:2,183:1,311:8,1729:8,1148:1,1042:9,1684:3,937:1,2383:2,107:2,367:5,422:1,1476:1,1983:5,517:1,1910:1,1539:1,1700:1,876:2,2176:2,872:1,1514:2,2395:5,2468:1,2121:1,893:1,1247:2,1100:13,340:2,1960:3,2291:1,1578:1,1238:1,268:1,1366:4,729:1,2057:1,784:2,599:2,161:6,1037:3,2138:1,138:4,659:3,1650:1,380:1,54:2,961:6,1306:2,457:1,1001:2,1912:3,2020:1,626:5,543:2,1367:4,2257:1,1756:3,26:6,1299:1,122:5,1229:1,1275:1,1057:9,515:1,1857:1,160:3,2509:1,991:1,1374:1,1407:2,1604:1,557:5,79:1,2295:1,2240:8,1361:1,1927:2,585:2,847:1,881:1,1039:1,488:2,1024:3,1227:2,1828:7,2254:1,645:1,1536:2,1084:8,1876:1,1101:1,216:2,1557:14,787:2,1462:1

# %%
# Output the sparse count vectors file
def output_txt(astring):
    text_file = open('Group006_count_vectors.txt', 'w')
    text_file.write(astring)
    text_file.close()

output_txt(output)

# %% [markdown]
# ### 4.9 End of the paper body pre-processing
#
# The pre-processing for paper body and the required txt output are finished sucessfully. The next part we will carry out the pre-processing for the paper title, abstract and authors.

# %% [markdown]
# ## 5. Text pre-processing of the titles, abstract and authors
#
# In this part, we extracted the different part of each article, and then process for each of them to get the output based on the assignment specification.

# %% [markdown]
# ### 5.1 Find top 10 most frequent Authors
#
# In this section, we used the regex `r'Authored by:(.*?)Abstract'` first to get the Author part, then use another regex `r'\n\n(.*)\n\n'` to get authors in one list, then using `split('\n')` to seprate all the authors. After we get all the authors, we output the top50 rather than top10 because there are many authors with the same times, for these authors, we need to sort them then output, so we first see the `most_common(50)` and get top10 from it after the list get sorted.

# %%
regex_author = r'Authored by:(.*?)Abstract'
author_result = []
for v in txtdic.values():
    author = re.findall(regex_author, v, re.DOTALL)
    regex_author2 = r'\n\n(.*)\n\n'
    author_list = re.findall(regex_author2, author[0], re.DOTALL)
    if len(author_list) > 0:
        temp = author_list[0].split('\n') # To extract the full name 
        temp1 = [x for x in temp if x != ''] # There is some papers without authors
        author_result += temp1
author_ten = FreqDist(author_result).most_common(50)
author_ten = sorted(author_ten, key=lambda x: (-x[1], x[0]))

author_ten_list = []
for i in author_ten[0:10]:
    author_ten_list.append(i[0])
author_ten_list
# Out:
# ['Dale Schuurmans',
#  'Hongyuan Zha',
#  'Lihong Li',
#  'Michael I. Jordan',
#  'Alex J. Smola',
#  'Alexander T. Ihler',
#  'Anima Anandkumar',
#  'Benjamin Recht',
#  'Constantine Caramanis',
#  'Dan Garber']

# %% [markdown]
# ### 5.2 Find Top 10 most frequent terms appearing in all Titles
#
# In this section, we first used the regex `r'(.*)\n?'` to get the title part from article, then create a new string names `title_content`, then for each article, we do the re.match function, we get the result and set it as lowercase to this string, then we used the same regex `r"[A-Za-z]\w+(?:[-'?]\w+)?"` to tokenize, after we get the tokenize result, we will get the top15 use the `mosr_common(15)` also to make sure the word with same appearing time can get sorted, after sorted, we output the top10 as our result.

# %%
# extract title and change to lower case

regex = r'(.*)\n?'
title_content = ''
for v in txtdic.values():
    title = re.match(regex, v)
    title_content += title.group(1).lower() + ' '
tokenizer = RegexpTokenizer(r"[A-Za-z]\w+(?:[-'?]\w+)?")
title_tokens = tokenizer.tokenize(title_content)
title_tokens2 = [w for w in title_tokens if w not in stopwords_set]
title_ten = FreqDist(title_tokens2).most_common(15)
title_ten = sorted(title_ten, key=lambda x: (-x[1], x[0]))
title_ten_list = []
for i in title_ten[0:10]:
    title_ten_list.append(i[0])
abstract_ten_list
title_ten_list
# Out:
# ['learning',
#  'bayesian',
#  'networks',
#  'online',
#  'optimal',
#  'models',
#  'stochastic',
#  'deep',
#  'model',
#  'sparse']

# %% [markdown]
# ### 5.3 Find Top 10 most frequent terms appearing in all Abstracts
#
# This part is semilar to the 5.2 part get the top 10 frequent terms in Titles. In this section, we first used the regex `r'Abstract(.*)Paper Body'` to get the abstract part from article, then create a new string names `string`, then for each article, we do the re.match function, we get the result and set it as lowercase to this string, then we used the same regex `r"[A-Za-z]\w+(?:[-'?]\w+)?"` to tokenize, after we get the tokenize result, we will get the top11 use the `mosr_common(11)` also to make sure the word with same appearing time can get sorted, after sorted, we output the top10 as our result3

# %%
# extract abstract and change the start of sentence to lower case

tokenizer = RegexpTokenizer(r"[A-Za-z]\w+(?:[-'?]\w+)?")
regex = r'Abstract(.*)Paper Body'
abstract_tokens = []
for v in txtdic.values():
    abstract = re.sub(r'(-\n)', '', v)
    abstract1 = re.sub(r'(\n)', ' ', abstract)
    abstract2 = re.findall(regex, abstract1)
    sentences = sent_detector.tokenize(abstract2[0].strip())
    string = ''
    for i in range(0,len(sentences)):
        string += sentences[i][0].lower() + sentences[i][1:]
    abstract_tokens += tokenizer.tokenize(string)
abstract_tokens2 = [w for w in abstract_tokens if w not in stopwords_set]
abstract_ten = FreqDist(abstract_tokens2).most_common(11)
abstract_ten_list = []
for i in abstract_ten[0:10]:
    abstract_ten_list.append(i[0])
abstract_ten_list
# Out:
# ['learning',
#  'algorithm',
#  'model',
#  'data',
#  'problem',
#  'show',
#  'method',
#  'methods',
#  'models',
#  'approach']

# %% [markdown]
# ### 5.4 Output our result as a file
#
# In this part, we used pandas package we imported to create the top 10 outputs as the dataframe, then use `df.to_csv` to output our dataframe result as the csv file.

# %%
csv_data = {
    'top10_terms_in_abstracts': abstract_ten_list,
    'top10_terms_in_titles': title_ten_list,
    'top10_authors': author_ten_list
}

df = pd.DataFrame(csv_data, columns = ['top10_terms_in_abstracts', 'top10_terms_in_titles', 'top10_authors'])
df.to_csv('Group006_stats.csv', index=False)

# %% [markdown]
# ### 5.5 End of the pre-processing of title, abstract and authors
#
# The text pre-processing of the title, abstract and authors are completed and the required csv file is output.

# %% [markdown]
# ## 6. Conclusion
#
# Through this assignment, we first carried out the text pre-processing tasks, including tokenization, stemming and several required tasks based on the assignment specification. Then, with the processed text, we output the required files, including the vocabulary index file, count vectors file and the csv file containing most top10 frequent terms. We learnt lots of knowledge and skills that used in text pre-processing and data wrangling.
